# %%
import csv
import numpy as np
import xlrd
import matplotlib.pyplot as plt

# %%
# !ls -lh
# TTS-10s.xlsx

# %%
workbook = xlrd.open_workbook("TTS-10s.xlsx")
# print(workbook.sheet_names())
sheet_9008 = workbook.sheet_by_name("9008")
sheet_9005 = workbook.sheet_by_name("9005")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-fd9c7897d271> in <module>()
# ----> 1 workbook = xlrd.open_workbook("TTS-10s.xlsx")
#       2 # print(workbook.sheet_names())
#       3 sheet_9008 = workbook.sheet_by_name("9008")
#       4 sheet_9005 = workbook.sheet_by_name("9005")
#
# ~/anaconda3_431/lib/python3.6/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     393         peek = file_contents[:peeksz]
#     394     else:
# --> 395         with open(filename, "rb") as f:
#     396             peek = f.read(peeksz)
#     397     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TTS-10s.xlsx'

# %%
import pandas as pd

xls = pd.ExcelFile('TTS-10s.xlsx')

df = xls.parse('9008', skiprows=1, index_col=1, na_values=['NA'])

# %%
df
# Out:
#            Date  Close  CHG  %CHG    V   MA5  MA25
# Time
# 15:00:00  42898    924  0.0  0.00  132  28.2  8.36
# 14:59:40  42898    924 -1.0 -0.10    6   2.2  3.12
# 14:59:20  42898    925  1.0  0.10    1   3.8  2.92
# 14:59:00  42898    924 -1.0 -0.10    1   5.0  2.92
# 14:58:30  42898    925  0.0  0.00    1   7.0  2.92
# 14:58:20  42898    925  0.0  0.00    2   7.0  2.92
# 14:58:00  42898    925  0.0  0.00   14   6.8  2.92
# 14:57:00  42898    925  0.0  0.00    7   4.2  2.48
# 14:56:30  42898    925  0.0  0.00   11   3.2  2.24
# 14:56:00  42898    925 -1.0 -0.10    1   3.8  1.84
# 14:54:20  42898    926  0.0  0.00    1   4.0  1.96
# 14:53:00  42898    926  1.0  0.10    1   4.0  2.20
# 14:51:10  42898    925  0.0  0.00    2   4.4  2.28
# 14:51:00  42898    925  1.0  0.10   14   4.2  2.24
# 14:50:10  42898    924  0.0  0.00    2   1.6  1.80
# 14:47:30  42898    924  0.0  0.00    1   1.4  1.76
# 14:46:40  42898    924  0.0  0.00    3   1.4  1.84
# ...

# %%
# !ls -lh
# Out:
# total 0
# -rw-r--r-- 1 nbuser nbuser 101K Jul 27 18:59 ATFS_01.ipynb
# -rw-r--r-- 1 nbuser nbuser 394K Jul 27 18:59 Fourier_PDE.ipynb
# -rw-r--r-- 1 nbuser nbuser  24K Sep 17 06:39 increase_speed_for_different_function.ipynb
# -rw-r--r-- 1 nbuser nbuser 4.8K Jul 27 18:59 three_doors.ipynb
# -rw-r--r-- 1 nbuser nbuser  28K Sep 20 07:48 topix-500.ipynb
# -rw-r--r-- 1 nbuser nbuser 634K Jul 27 18:59 traffic_simulation.ipynb
